# %%
import dgl
import torch
import scipy.sparse as sp

# %%
sp_mat = sp.rand(100,100,density=0.05)
g_sp = dgl.from_scipy(sp_mat)
g_sp
# Out:
# Graph(num_nodes=100, num_edges=500,
#       ndata_schemes={}
#       edata_schemes={})

# %%
g_sp.edges()
# Out:
# (tensor([49, 76, 11, 19, 20, 25, 71,  8, 86, 62, 83, 36, 64, 29,  0, 66, 42, 34,
#           4, 21, 47,  8, 36, 12, 70, 77,  6, 65, 51, 44, 78, 71, 69, 81,  1, 22,
#          89, 33,  0,  9,  4, 23,  9,  0,  8,  5, 72, 59, 34, 84,  2, 28, 97, 30,
#          73, 45,  2, 31, 14, 71, 88,  9,  5, 84, 98, 93, 39, 79, 67,  9, 34, 97,
#          59,  8, 29, 29, 11, 40, 91, 41, 63, 24, 77, 51, 18, 12, 10, 69, 84, 86,
#          85, 68, 36, 57, 16, 12, 44, 34,  3, 26, 93, 68, 45, 76, 15, 87, 20, 80,
#          33, 58, 64, 54, 57,  0, 57, 21, 49, 53, 10, 54,  3, 37, 91, 35, 11, 20,
#          60, 40, 22, 35, 56, 60, 70, 18, 86, 41, 38, 83, 14, 65, 61, 81, 67, 13,
#          24, 44,  0, 53, 82, 69, 43, 43, 88, 13, 68, 92, 93, 66, 18, 99, 52, 84,
#           7, 38, 35, 29, 65, 41, 45, 41, 26, 83, 25, 63, 66, 99, 25, 80, 28, 83,
#          64, 58, 48, 58, 14, 24, 75, 23,  1, 26, 56, 35, 98, 80,  7, 24, 42, 34,
#          32, 85, 61, 58, 65,  8, 84, 19, 26, 17, 49, 92, 25, 27, 86, 26, 19, 17,
# ...

# %%
import networkx as nx
nx_g = nx.path_graph(5)
g_nx = dgl.from_networkx(nx_g)
g_nx
# Out:
# Graph(num_nodes=5, num_edges=8,
#       ndata_schemes={}
#       edata_schemes={})

# %%
g_nx.edges()
# Out:
# (tensor([0, 1, 1, 2, 2, 3, 3, 4]), tensor([1, 0, 2, 1, 3, 2, 4, 3]))

# %%
nx_dig = nx.DiGraph([(2, 1), (1, 2), (2, 3), (0, 0)])
dig_nx = dgl.from_networkx(nx_dig)
dig_nx
# Out:
# Graph(num_nodes=4, num_edges=4,
#       ndata_schemes={}
#       edata_schemes={})
